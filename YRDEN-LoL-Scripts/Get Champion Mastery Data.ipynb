# %%
import sys
import time
import datetime
import json
import constants
import requests
import psycopg

from riotwatcher import LolWatcher, ValWatcher, ApiError, RiotWatcher

import match_fetcher

# %%
YrdenPass = constants.db_password
host_ip = constants.db_ip

# %%
lol_watcher = LolWatcher(constants.API_KEY_SERVICE)
riot_watcher = RiotWatcher(constants.API_KEY_SERVICE)
api_key = constants.API_KEY_SERVICE

# %%
YrdenPass = constants.db_password
host_ip = constants.db_ip
#Connect to Yrden DB
#Private args are executed and then deleted for safety
db_connection = f'dbname=YRDEN user=postgres password={YrdenPass} host={host_ip}'

conn = psycopg.connect(db_connection)

#Creates a cursor for db operations
cur = conn.cursor()

# %%
cur.execute('SELECT riot_puuid FROM "YRDEN".yrden_people WHERE summoner_name is NOT NULL AND riot_puuid is NOT NULL')
result = cur.fetchall()
res = [result[0] for result in result]
res
# Out:
# ['oFdCaHSdLE-umAd_AUTwskzbTOEPp-CU7-73Gv7wTpF2TWKw18JTx8F86EzUTMf6goBR9ZVoAwFUWA',
#  'Hd3lUYJgb7DENibojGOd_jOBjNUojDepDeCs6OLxHF80NkRdwr9UA_BJK5qQUD7h6wacRJ42sb8uPA',
#  'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#  'verjeqL6V6X4yDSQ6frKQSdh_u9OjwMfp9YJ3jetwkcNj-tyzov3zduVtY-SEVUGAQ_hz4lLE7URsA',
#  'QQJnzlpLTSBZvRvKUe4MDfJiFGAf3G-IDy0T96h7gCB5T9BN40K9tBzpg2SnFP55oxdqI8LTUQZGeg',
#  '0CpS1bKgKnH7IKuMVnpeOpyLFIj3J78S1jpxZmOx3EZq4jNp4LyIChKBAbfwpnh0of9ooKp7h8VaPQ',
#  'Xhi01hd4YPU92OGkFKSsqEnTtVwTD_lERDpFttdWrpKSPBBZ698GvDYGkYEeq31DVz67O3oNNlEgSw',
#  'HmOcVn8rE4ArEVltljRl4pWndPLIPRf9GTG3WA_vyrJXJ7fQLVGXqZ1yYVgBTXxn3-x2ACphfh9Syw',
#  'VzvO1bwgi0OQCnxU96D0R-wrrCp4aM9qbA4R0lSJ9ZMPD3gRVSsfxRI5x7KUJdlY0205lG862-tywQ',
#  'nQd7Ylk472T9NtwuS-hhuLDcxoUg71HK60rRIvJY1b9YMylIjeQKRVzA6p3L7RTm7OMfNISOQMR-5Q',
#  '84_xB7Ms1eQbyvGb6w7SKbxPm2AtlUUfCHgqF5WrgKNhpeppB8uzrtS6osCVQ5afvmVWAcnmXZWROg',
#  'a62cDaHm9nna2bWRLfiDZ2foba7f-aK663hWCJiEr8M1p9MRM9LnXO4ZBBO3j9X3oYUqvuspiKJt2w',
#  '4FdoGw1rNXZ0MlNGI3hO4bCdsDlDytyErpwmyILjPH72gweicSVjetUQ2AmVYCra7HEUYJqjLLJDhw',
#  'wp8hfqNkCSr7gMPHEVnuVKn-fLVTKjI5EKsueD0pwp7CQ26osy8Q94-cg19v8GymHdqiBsow979r6Q']

# %%
cur.execute(''' SELECT RIOT_PUUID FROM "YRDEN".YRDEN_PEOPLE WHERE RIOT_PUUID IS NOT NULL;''')
puuids = cur.fetchall()

lol_watcher.summoner.by_puuid('na1', puuids[2])
# Out:
# {'id': 'kFIKtjYdraYAo5B2Stz2H9G8Pm_tER1-usRFbQMSlUJ92wc',
#  'accountId': '8kvriQI1e0E1m6ZsV6fw8HWs5QYPr088Cvy9DU_EPre_y3I',
#  'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#  'name': 'Antzi',
#  'profileIconId': 4407,
#  'revisionDate': 1702876133065,
#  'summonerLevel': 830}

# %%
summoner_ids = {}
cur.execute('''SELECT summoner_id FROM "YRDEN".yrden_people WHERE summoner_id IS NOT NULL;''')
result = cur.fetchall()
result
# Out:
# [('NIjHCSkwyUmf5e7g54OhPRci_L9vPh4gs54eEhIF4BBdihs',),
#  ('9vOEt6pNlVxMBoaOwzqum4hkIeGSHL3MxCdIIvhCi26RPPE',),
#  ('kFIKtjYdraYAo5B2Stz2H9G8Pm_tER1-usRFbQMSlUJ92wc',),
#  ('hG0EMEDSLadFMgiqkRzeO73TlHrE9U6hkXVM1hG-f6tDkug',),
#  ('qZDiiKmSUHCv7mAaZi0uLoiCuJS7MwJeR7LOsM32FOLeJk0',),
#  ('1g5Gu9JPJ1SY7xe0F5D0SN87VCzVOo_1O80BZVHF7alY5bQ',),
#  ('lZ5x4X43CIY2KEy2TVnhL8CKzia0hZXDW2mfULy3CUjTAPs',),
#  ('3ESf1Y_PigqlszeVJMs2Hyy2crhTOGY0Md47fBXV3NeKHmU',),
#  ('9M6pduy8wejqoXUpz17ZszkvTJv5BGUR9_A4pcZFbxi6MT8',),
#  ('Wvn0dFkr7o8s4Udrh-P4bonOcTINYrOizVhlZufJaJQ-E4c',),
#  ('VuTUVP490aBM6hTJX0BVBq9JhlbOlH8HtfjZKOKBX6NBc6U',),
#  ('EAZqsPSSQkUUPZ8cnTcSZhDwIEWnWn9KvcT-7f8dGAlzdQM',),
#  ('TQBQJfHgCl_cYkR3B1lqC1wdvPW6C1fiufgiiQz-0_WHLPQ',),
#  ('jTaF-pVnbaPRouuvCPGkG29xcHzPQ54mfAnp-glTRcJ8xJM',)]

# %%
lol_watcher.champion_mastery.by_summoner('na1', result[5][0])
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\riotwatcher\Handlers\ThrowOnErrorHandler.py:18, in ThrowOnErrorHandler.after_request(self, region, endpoint_name, method_name, url, response)
#      17 try:
# ---> 18     response.raise_for_status()
#      19 except requests.HTTPError as err:
#
# File ~\anaconda3\lib\site-packages\requests\models.py:960, in Response.raise_for_status(self)
#     959 if http_error_msg:
# --> 960     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 404 Client Error: Not Found for url: https://na1.api.riotgames.com/lol/champion-mastery/v4/champion-masteries/by-summoner/1g5Gu9JPJ1SY7xe0F5D0SN87VCzVOo_1O80BZVHF7alY5bQ
#
# During handling of the above exception, another exception occurred:
#
# HTTPError                                 Traceback (most recent call last)
# Input In [31], in <cell line: 1>()
# ----> 1 lol_watcher.champion_mastery.by_summoner('na1', result[5][0])
#
# File ~\anaconda3\lib\site-packages\riotwatcher\_apis\league_of_legends\ChampionMasteryApiV4.py:32, in ChampionMasteryApiV4.by_summoner(self, region, encrypted_summoner_id)
#      21 def by_summoner(self, region: str, encrypted_summoner_id: str):
#      22     """
#      23     Get all champion mastery entries.
#      24
#    (...)
#      30                                         combination.
#      31     """
# ---> 32     return self._request_endpoint(
#      33         self.by_summoner.__name__,
#      34         region,
#      35         ChampionMasteryApiV4Urls.by_summoner,
#      36         encrypted_summoner_id=encrypted_summoner_id,
#      37     )
#
# File ~\anaconda3\lib\site-packages\riotwatcher\_apis\NamedEndpoint.py:36, in NamedEndpoint._request_endpoint(self, method_name, region, endpoint, **kwargs)
#      26 """
#      27 Sends a request through the BaseApi instance provided, injecting the provided
#      28 endpoint_name into the method call, so the caller doesn't have to.
#    (...)
#      33                             parameters
#      34 """
#      35 url, query = endpoint(platform=region, **kwargs)
# ---> 36 return self._base_api.raw_request(
#      37     self._endpoint_name, method_name, region, url, query
#      38 )
#
# File ~\anaconda3\lib\site-packages\riotwatcher\_apis\BaseApi.py:51, in BaseApi.raw_request(self, endpoint_name, method_name, region, url, query_params)
#      49 if self._request_handlers is not None:
#      50     for handler in self._request_handlers[early_ret_idx:None:-1]:
# ---> 51         mod = handler.after_request(
#      52             region, endpoint_name, method_name, url, response
#      53         )
#      54         if mod is not None:
#      55             response = mod
#
# File ~\anaconda3\lib\site-packages\riotwatcher\Handlers\ThrowOnErrorHandler.py:20, in ThrowOnErrorHandler.after_request(self, region, endpoint_name, method_name, url, response)
#      18     response.raise_for_status()
#      19 except requests.HTTPError as err:
# ---> 20     raise ApiError(*err.args, request=err.request, response=err.response)
#
# HTTPError: 404 Client Error: Not Found for url: https://na1.api.riotgames.com/lol/champion-mastery/v4/champion-masteries/by-summoner/1g5Gu9JPJ1SY7xe0F5D0SN87VCzVOo_1O80BZVHF7alY5bQ

# %%
#Creating Champion Mastery Table

cur.execute ('''DROP TABLE
              "YRDEN".lol_champ_mastery''')
cur.execute('''CREATE TABLE "YRDEN".lol_champ_mastery
            (puuid varchar , 
            summonerId varchar,
            championId int , 
            championLevel int ,
            championPoints int ,
            championPointsUntilNextLevel int,
            championPointsSinceLastLevel int,
            chestGranted boolean,
            lastPlayTime timestamp,
            tokensEarned int
            )
            ;
            ''')
conn.commit()

# %%
result[1]
res = [result[0] for result in result]

# %%
result
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [20], in <cell line: 1>()
# ----> 1 result
#
# NameError: name 'result' is not defined

# %%
res

# %%
"""
for n in range(len(result)):
    vals = lol_watcher.champion_mastery.by_summoner('na1', result[n])
    new_vals = {}
    for i in range(len(vals)):
        new_vals.update({'puuid' : vals[n]['puuid'],
                                'summonerId' : vals[n]['summonerId'],
                                 'championId' : vals[n]['championId'],
                                 'championLevel' : vals[n]['championLevel'],
                                 'championPoints' :  vals[n]['championPoints'],
                                 'championPointsUntilNextLevel' :  vals[n]['championPointsUntilNextLevel'],
                                 'championPoinstSinceLastLevel' :  vals[n]['championPointsSinceLastLevel'],
                                 'chestGranted' :  vals[n]['chestGranted'],
                                 'lastPlayTime' :  vals[n]['lastPlayTime'],
                                 'tokensEarned' :  vals[n]['tokensEarned']
                                })
        print(new_vals)
        """

# %%
timestamp_in_milliseconds = 1700529785000
timestamp_in_seconds = timestamp_in_milliseconds / 1000

dt_object = datetime.datetime.fromtimestamp(timestamp_in_seconds)
print(dt_object)
print(timestamp_in_seconds)

# %%
lol_watcher.champion_mastery.by_summoner('na1', 'pehrpiJgcFnMT07UJyGZQ2TESuv0ndIBChe41GVtKw6ehhE')[0]['lastPlayTime']/1000

# %%
print(datetime.datetime.fromtimestamp(lol_watcher.champion_mastery.by_summoner('na1', 'pehrpiJgcFnMT07UJyGZQ2TESuv0ndIBChe41GVtKw6ehhE')[0]['lastPlayTime']/1000))

# %%
cur.execute('SELECT riot_puuid FROM "YRDEN".yrden_people WHERE summoner_name is NOT NULL AND riot_puuid is NOT NULL')
result = cur.fetchall()
res = [result[0] for result in result]
res
# Out:
# ['oFdCaHSdLE-umAd_AUTwskzbTOEPp-CU7-73Gv7wTpF2TWKw18JTx8F86EzUTMf6goBR9ZVoAwFUWA',
#  'Hd3lUYJgb7DENibojGOd_jOBjNUojDepDeCs6OLxHF80NkRdwr9UA_BJK5qQUD7h6wacRJ42sb8uPA',
#  'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#  'verjeqL6V6X4yDSQ6frKQSdh_u9OjwMfp9YJ3jetwkcNj-tyzov3zduVtY-SEVUGAQ_hz4lLE7URsA',
#  'QQJnzlpLTSBZvRvKUe4MDfJiFGAf3G-IDy0T96h7gCB5T9BN40K9tBzpg2SnFP55oxdqI8LTUQZGeg',
#  '0CpS1bKgKnH7IKuMVnpeOpyLFIj3J78S1jpxZmOx3EZq4jNp4LyIChKBAbfwpnh0of9ooKp7h8VaPQ',
#  'Xhi01hd4YPU92OGkFKSsqEnTtVwTD_lERDpFttdWrpKSPBBZ698GvDYGkYEeq31DVz67O3oNNlEgSw',
#  'HmOcVn8rE4ArEVltljRl4pWndPLIPRf9GTG3WA_vyrJXJ7fQLVGXqZ1yYVgBTXxn3-x2ACphfh9Syw',
#  'VzvO1bwgi0OQCnxU96D0R-wrrCp4aM9qbA4R0lSJ9ZMPD3gRVSsfxRI5x7KUJdlY0205lG862-tywQ',
#  'nQd7Ylk472T9NtwuS-hhuLDcxoUg71HK60rRIvJY1b9YMylIjeQKRVzA6p3L7RTm7OMfNISOQMR-5Q',
#  '84_xB7Ms1eQbyvGb6w7SKbxPm2AtlUUfCHgqF5WrgKNhpeppB8uzrtS6osCVQ5afvmVWAcnmXZWROg',
#  'a62cDaHm9nna2bWRLfiDZ2foba7f-aK663hWCJiEr8M1p9MRM9LnXO4ZBBO3j9X3oYUqvuspiKJt2w',
#  '4FdoGw1rNXZ0MlNGI3hO4bCdsDlDytyErpwmyILjPH72gweicSVjetUQ2AmVYCra7HEUYJqjLLJDhw',
#  'wp8hfqNkCSr7gMPHEVnuVKn-fLVTKjI5EKsueD0pwp7CQ26osy8Q94-cg19v8GymHdqiBsow979r6Q']

# %%
for n, riot_puuid in enumerate(res):
    print(riot_puuid)
# Out:
# oFdCaHSdLE-umAd_AUTwskzbTOEPp-CU7-73Gv7wTpF2TWKw18JTx8F86EzUTMf6goBR9ZVoAwFUWA
# Hd3lUYJgb7DENibojGOd_jOBjNUojDepDeCs6OLxHF80NkRdwr9UA_BJK5qQUD7h6wacRJ42sb8uPA
# lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A
# verjeqL6V6X4yDSQ6frKQSdh_u9OjwMfp9YJ3jetwkcNj-tyzov3zduVtY-SEVUGAQ_hz4lLE7URsA
# QQJnzlpLTSBZvRvKUe4MDfJiFGAf3G-IDy0T96h7gCB5T9BN40K9tBzpg2SnFP55oxdqI8LTUQZGeg
# 0CpS1bKgKnH7IKuMVnpeOpyLFIj3J78S1jpxZmOx3EZq4jNp4LyIChKBAbfwpnh0of9ooKp7h8VaPQ
# Xhi01hd4YPU92OGkFKSsqEnTtVwTD_lERDpFttdWrpKSPBBZ698GvDYGkYEeq31DVz67O3oNNlEgSw
# HmOcVn8rE4ArEVltljRl4pWndPLIPRf9GTG3WA_vyrJXJ7fQLVGXqZ1yYVgBTXxn3-x2ACphfh9Syw
# VzvO1bwgi0OQCnxU96D0R-wrrCp4aM9qbA4R0lSJ9ZMPD3gRVSsfxRI5x7KUJdlY0205lG862-tywQ
# nQd7Ylk472T9NtwuS-hhuLDcxoUg71HK60rRIvJY1b9YMylIjeQKRVzA6p3L7RTm7OMfNISOQMR-5Q
# 84_xB7Ms1eQbyvGb6w7SKbxPm2AtlUUfCHgqF5WrgKNhpeppB8uzrtS6osCVQ5afvmVWAcnmXZWROg
# a62cDaHm9nna2bWRLfiDZ2foba7f-aK663hWCJiEr8M1p9MRM9LnXO4ZBBO3j9X3oYUqvuspiKJt2w
# 4FdoGw1rNXZ0MlNGI3hO4bCdsDlDytyErpwmyILjPH72gweicSVjetUQ2AmVYCra7HEUYJqjLLJDhw
# wp8hfqNkCSr7gMPHEVnuVKn-fLVTKjI5EKsueD0pwp7CQ26osy8Q94-cg19v8GymHdqiBsow979r6Q

# %%
puuid = 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A'

# %%
api_url = f"https://na1.api.riotgames.com/lol/champion-mastery/v4/champion-masteries/by-puuid/{puuid}?api_key={api_key}"

# %%
requests.get(api_url)
# Out:
# <Response [200]>

# %%
resp = requests.get(api_url)

# %%
mastery_info = resp.json()
mastery_info
# Out:
# [{'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 99,
#   'championLevel': 7,
#   'championPoints': 470788,
#   'lastPlayTime': 1702870310000,
#   'championPointsSinceLastLevel': 449188,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': True,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 22,
#   'championLevel': 7,
#   'championPoints': 338152,
#   'lastPlayTime': 1702434731000,
#   'championPointsSinceLastLevel': 316552,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': True,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 40,
#   'championLevel': 7,
#   'championPoints': 258065,
#   'lastPlayTime': 1702183724000,
#   'championPointsSinceLastLevel': 236465,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 235,
#   'championLevel': 7,
#   'championPoints': 243154,
#   'lastPlayTime': 1702140973000,
#   'championPointsSinceLastLevel': 221554,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 25,
#   'championLevel': 7,
#   'championPoints': 195963,
#   'lastPlayTime': 1700379620000,
#   'championPointsSinceLastLevel': 174363,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 16,
#   'championLevel': 7,
#   'championPoints': 186639,
#   'lastPlayTime': 1702019113000,
#   'championPointsSinceLastLevel': 165039,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': True,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 21,
#   'championLevel': 7,
#   'championPoints': 176315,
#   'lastPlayTime': 1702603239000,
#   'championPointsSinceLastLevel': 154715,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 67,
#   'championLevel': 7,
#   'championPoints': 170642,
#   'lastPlayTime': 1702876133000,
#   'championPointsSinceLastLevel': 149042,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 147,
#   'championLevel': 7,
#   'championPoints': 166571,
#   'lastPlayTime': 1702179311000,
#   'championPointsSinceLastLevel': 144971,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': True,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 55,
#   'championLevel': 6,
#   'championPoints': 159033,
#   'lastPlayTime': 1702860244000,
#   'championPointsSinceLastLevel': 137433,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': False,
#   'tokensEarned': 2,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 37,
#   'championLevel': 7,
#   'championPoints': 152149,
#   'lastPlayTime': 1701212362000,
#   'championPointsSinceLastLevel': 130549,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 10,
#   'championLevel': 7,
#   'championPoints': 149433,
#   'lastPlayTime': 1702523252000,
#   'championPointsSinceLastLevel': 127833,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 103,
#   'championLevel': 7,
#   'championPoints': 123055,
#   'lastPlayTime': 1702862391000,
#   'championPointsSinceLastLevel': 101455,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 15,
#   'championLevel': 7,
#   'championPoints': 118600,
#   'lastPlayTime': 1702790937000,
#   'championPointsSinceLastLevel': 97000,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 117,
#   'championLevel': 7,
#   'championPoints': 111524,
#   'lastPlayTime': 1687621700000,
#   'championPointsSinceLastLevel': 89924,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 143,
#   'championLevel': 7,
#   'championPoints': 110825,
#   'lastPlayTime': 1690671958000,
#   'championPointsSinceLastLevel': 89225,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 92,
#   'championLevel': 5,
#   'championPoints': 108203,
#   'lastPlayTime': 1702751007000,
#   'championPointsSinceLastLevel': 86603,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 51,
#   'championLevel': 7,
#   'championPoints': 105707,
#   'lastPlayTime': 1701220766000,
#   'championPointsSinceLastLevel': 84107,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 222,
#   'championLevel': 7,
#   'championPoints': 93927,
#   'lastPlayTime': 1702762640000,
#   'championPointsSinceLastLevel': 72327,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 39,
#   'championLevel': 7,
#   'championPoints': 88356,
#   'lastPlayTime': 1702789407000,
#   'championPointsSinceLastLevel': 66756,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 145,
#   'championLevel': 6,
#   'championPoints': 88296,
#   'lastPlayTime': 1702246221000,
#   'championPointsSinceLastLevel': 66696,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': False,
#   'tokensEarned': 1,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 81,
#   'championLevel': 7,
#   'championPoints': 83161,
#   'lastPlayTime': 1702352697000,
#   'championPointsSinceLastLevel': 61561,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 43,
#   'championLevel': 7,
#   'championPoints': 82368,
#   'lastPlayTime': 1702764953000,
#   'championPointsSinceLastLevel': 60768,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 131,
#   'championLevel': 7,
#   'championPoints': 79084,
#   'lastPlayTime': 1688963832000,
#   'championPointsSinceLastLevel': 57484,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 1,
#   'championLevel': 7,
#   'championPoints': 77827,
#   'lastPlayTime': 1701543825000,
#   'championPointsSinceLastLevel': 56227,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 90,
#   'championLevel': 6,
#   'championPoints': 74444,
#   'lastPlayTime': 1702189584000,
#   'championPointsSinceLastLevel': 52844,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 110,
#   'championLevel': 6,
#   'championPoints': 65659,
#   'lastPlayTime': 1688274734000,
#   'championPointsSinceLastLevel': 44059,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 412,
#   'championLevel': 7,
#   'championPoints': 64739,
#   'lastPlayTime': 1702872316000,
#   'championPointsSinceLastLevel': 43139,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 267,
#   'championLevel': 7,
#   'championPoints': 58408,
#   'lastPlayTime': 1690654629000,
#   'championPointsSinceLastLevel': 36808,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 29,
#   'championLevel': 6,
#   'championPoints': 53047,
#   'lastPlayTime': 1702838416000,
#   'championPointsSinceLastLevel': 31447,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 134,
#   'championLevel': 6,
#   'championPoints': 50678,
#   'lastPlayTime': 1702865529000,
#   'championPointsSinceLastLevel': 29078,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': True,
#   'tokensEarned': 2,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 61,
#   'championLevel': 6,
#   'championPoints': 49929,
#   'lastPlayTime': 1689042831000,
#   'championPointsSinceLastLevel': 28329,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': False,
#   'tokensEarned': 1,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 18,
#   'championLevel': 5,
#   'championPoints': 48805,
#   'lastPlayTime': 1702836266000,
#   'championPointsSinceLastLevel': 27205,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 498,
#   'championLevel': 6,
#   'championPoints': 48705,
#   'lastPlayTime': 1702270067000,
#   'championPointsSinceLastLevel': 27105,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': True,
#   'tokensEarned': 1,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 89,
#   'championLevel': 6,
#   'championPoints': 46706,
#   'lastPlayTime': 1690666961000,
#   'championPointsSinceLastLevel': 25106,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': True,
#   'tokensEarned': 2,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 112,
#   'championLevel': 5,
#   'championPoints': 44696,
#   'lastPlayTime': 1681003709000,
#   'championPointsSinceLastLevel': 23096,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': False,
#   'tokensEarned': 1,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 63,
#   'championLevel': 6,
#   'championPoints': 41164,
#   'lastPlayTime': 1702093772000,
#   'championPointsSinceLastLevel': 19564,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 17,
#   'championLevel': 6,
#   'championPoints': 40157,
#   'lastPlayTime': 1701021440000,
#   'championPointsSinceLastLevel': 18557,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 50,
#   'championLevel': 6,
#   'championPoints': 38379,
#   'lastPlayTime': 1701584666000,
#   'championPointsSinceLastLevel': 16779,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': True,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 98,
#   'championLevel': 5,
#   'championPoints': 38247,
#   'lastPlayTime': 1688869060000,
#   'championPointsSinceLastLevel': 16647,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': False,
#   'tokensEarned': 1,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 102,
#   'championLevel': 5,
#   'championPoints': 38218,
#   'lastPlayTime': 1688599093000,
#   'championPointsSinceLastLevel': 16618,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 876,
#   'championLevel': 5,
#   'championPoints': 37784,
#   'lastPlayTime': 1702138699000,
#   'championPointsSinceLastLevel': 16184,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 429,
#   'championLevel': 6,
#   'championPoints': 37706,
#   'lastPlayTime': 1702436962000,
#   'championPointsSinceLastLevel': 16106,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': False,
#   'tokensEarned': 1,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 69,
#   'championLevel': 6,
#   'championPoints': 36149,
#   'lastPlayTime': 1701916581000,
#   'championPointsSinceLastLevel': 14549,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 518,
#   'championLevel': 5,
#   'championPoints': 35847,
#   'lastPlayTime': 1702428805000,
#   'championPointsSinceLastLevel': 14247,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': False,
#   'tokensEarned': 1,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 887,
#   'championLevel': 5,
#   'championPoints': 35657,
#   'lastPlayTime': 1700539444000,
#   'championPointsSinceLastLevel': 14057,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 96,
#   'championLevel': 5,
#   'championPoints': 33191,
#   'lastPlayTime': 1701308851000,
#   'championPointsSinceLastLevel': 11591,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 45,
#   'championLevel': 5,
#   'championPoints': 31152,
#   'lastPlayTime': 1702864066000,
#   'championPointsSinceLastLevel': 9552,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 203,
#   'championLevel': 5,
#   'championPoints': 31092,
#   'lastPlayTime': 1693845633000,
#   'championPointsSinceLastLevel': 9492,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': False,
#   'tokensEarned': 1,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 9,
#   'championLevel': 6,
#   'championPoints': 30494,
#   'lastPlayTime': 1701142371000,
#   'championPointsSinceLastLevel': 8894,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 236,
#   'championLevel': 5,
#   'championPoints': 29441,
#   'lastPlayTime': 1689437859000,
#   'championPointsSinceLastLevel': 7841,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 221,
#   'championLevel': 5,
#   'championPoints': 27903,
#   'lastPlayTime': 1702873933000,
#   'championPointsSinceLastLevel': 6303,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': True,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 245,
#   'championLevel': 5,
#   'championPoints': 26146,
#   'lastPlayTime': 1686890197000,
#   'championPointsSinceLastLevel': 4546,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 44,
#   'championLevel': 5,
#   'championPoints': 25425,
#   'lastPlayTime': 1690040633000,
#   'championPointsSinceLastLevel': 3825,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': False,
#   'tokensEarned': 1,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 202,
#   'championLevel': 5,
#   'championPoints': 25174,
#   'lastPlayTime': 1689479360000,
#   'championPointsSinceLastLevel': 3574,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 60,
#   'championLevel': 5,
#   'championPoints': 25048,
#   'lastPlayTime': 1686465160000,
#   'championPointsSinceLastLevel': 3448,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 497,
#   'championLevel': 5,
#   'championPoints': 24509,
#   'lastPlayTime': 1683603774000,
#   'championPointsSinceLastLevel': 2909,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 8,
#   'championLevel': 5,
#   'championPoints': 24308,
#   'lastPlayTime': 1684040942000,
#   'championPointsSinceLastLevel': 2708,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 26,
#   'championLevel': 5,
#   'championPoints': 24269,
#   'lastPlayTime': 1680914777000,
#   'championPointsSinceLastLevel': 2669,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 150,
#   'championLevel': 5,
#   'championPoints': 23652,
#   'lastPlayTime': 1701728958000,
#   'championPointsSinceLastLevel': 2052,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 141,
#   'championLevel': 5,
#   'championPoints': 23578,
#   'lastPlayTime': 1701307424000,
#   'championPointsSinceLastLevel': 1978,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 104,
#   'championLevel': 5,
#   'championPoints': 22477,
#   'lastPlayTime': 1679960970000,
#   'championPointsSinceLastLevel': 877,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 30,
#   'championLevel': 5,
#   'championPoints': 22441,
#   'lastPlayTime': 1684102437000,
#   'championPointsSinceLastLevel': 841,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 127,
#   'championLevel': 5,
#   'championPoints': 22253,
#   'lastPlayTime': 1684101175000,
#   'championPointsSinceLastLevel': 653,
#   'championPointsUntilNextLevel': 0,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 350,
#   'championLevel': 4,
#   'championPoints': 21078,
#   'lastPlayTime': 1701491425000,
#   'championPointsSinceLastLevel': 8478,
#   'championPointsUntilNextLevel': 522,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 427,
#   'championLevel': 4,
#   'championPoints': 20161,
#   'lastPlayTime': 1688957690000,
#   'championPointsSinceLastLevel': 7561,
#   'championPointsUntilNextLevel': 1439,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 201,
#   'championLevel': 4,
#   'championPoints': 19980,
#   'lastPlayTime': 1669746692000,
#   'championPointsSinceLastLevel': 7380,
#   'championPointsUntilNextLevel': 1620,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 28,
#   'championLevel': 4,
#   'championPoints': 19070,
#   'lastPlayTime': 1688437361000,
#   'championPointsSinceLastLevel': 6470,
#   'championPointsUntilNextLevel': 2530,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 23,
#   'championLevel': 4,
#   'championPoints': 18608,
#   'lastPlayTime': 1702182670000,
#   'championPointsSinceLastLevel': 6008,
#   'championPointsUntilNextLevel': 2992,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 360,
#   'championLevel': 4,
#   'championPoints': 17794,
#   'lastPlayTime': 1702607181000,
#   'championPointsSinceLastLevel': 5194,
#   'championPointsUntilNextLevel': 3806,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 142,
#   'championLevel': 4,
#   'championPoints': 17694,
#   'lastPlayTime': 1685287572000,
#   'championPointsSinceLastLevel': 5094,
#   'championPointsUntilNextLevel': 3906,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 157,
#   'championLevel': 4,
#   'championPoints': 16803,
#   'lastPlayTime': 1702233015000,
#   'championPointsSinceLastLevel': 4203,
#   'championPointsUntilNextLevel': 4797,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 57,
#   'championLevel': 4,
#   'championPoints': 16554,
#   'lastPlayTime': 1687146888000,
#   'championPointsSinceLastLevel': 3954,
#   'championPointsUntilNextLevel': 5046,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 85,
#   'championLevel': 4,
#   'championPoints': 15969,
#   'lastPlayTime': 1665801819000,
#   'championPointsSinceLastLevel': 3369,
#   'championPointsUntilNextLevel': 5631,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 254,
#   'championLevel': 4,
#   'championPoints': 15653,
#   'lastPlayTime': 1688788630000,
#   'championPointsSinceLastLevel': 3053,
#   'championPointsUntilNextLevel': 5947,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 161,
#   'championLevel': 4,
#   'championPoints': 15520,
#   'lastPlayTime': 1680314916000,
#   'championPointsSinceLastLevel': 2920,
#   'championPointsUntilNextLevel': 6080,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 68,
#   'championLevel': 4,
#   'championPoints': 15217,
#   'lastPlayTime': 1702016396000,
#   'championPointsSinceLastLevel': 2617,
#   'championPointsUntilNextLevel': 6383,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 902,
#   'championLevel': 4,
#   'championPoints': 15042,
#   'lastPlayTime': 1702247210000,
#   'championPointsSinceLastLevel': 2442,
#   'championPointsUntilNextLevel': 6558,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 84,
#   'championLevel': 4,
#   'championPoints': 14926,
#   'lastPlayTime': 1700947137000,
#   'championPointsSinceLastLevel': 2326,
#   'championPointsUntilNextLevel': 6674,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 4,
#   'championLevel': 4,
#   'championPoints': 14277,
#   'lastPlayTime': 1687822898000,
#   'championPointsSinceLastLevel': 1677,
#   'championPointsUntilNextLevel': 7323,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 200,
#   'championLevel': 4,
#   'championPoints': 14256,
#   'lastPlayTime': 1701730472000,
#   'championPointsSinceLastLevel': 1656,
#   'championPointsUntilNextLevel': 7344,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 53,
#   'championLevel': 4,
#   'championPoints': 13824,
#   'lastPlayTime': 1688952869000,
#   'championPointsSinceLastLevel': 1224,
#   'championPointsUntilNextLevel': 7776,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 31,
#   'championLevel': 4,
#   'championPoints': 13199,
#   'lastPlayTime': 1701582409000,
#   'championPointsSinceLastLevel': 599,
#   'championPointsUntilNextLevel': 8401,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 119,
#   'championLevel': 4,
#   'championPoints': 13111,
#   'lastPlayTime': 1676866994000,
#   'championPointsSinceLastLevel': 511,
#   'championPointsUntilNextLevel': 8489,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 77,
#   'championLevel': 4,
#   'championPoints': 12754,
#   'lastPlayTime': 1701580948000,
#   'championPointsSinceLastLevel': 154,
#   'championPointsUntilNextLevel': 8846,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 41,
#   'championLevel': 4,
#   'championPoints': 12725,
#   'lastPlayTime': 1701827485000,
#   'championPointsSinceLastLevel': 125,
#   'championPointsUntilNextLevel': 8875,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 163,
#   'championLevel': 4,
#   'championPoints': 12718,
#   'lastPlayTime': 1702828225000,
#   'championPointsSinceLastLevel': 118,
#   'championPointsUntilNextLevel': 8882,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 101,
#   'championLevel': 4,
#   'championPoints': 12703,
#   'lastPlayTime': 1684036849000,
#   'championPointsSinceLastLevel': 103,
#   'championPointsUntilNextLevel': 8897,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 76,
#   'championLevel': 3,
#   'championPoints': 12400,
#   'lastPlayTime': 1675545162000,
#   'championPointsSinceLastLevel': 6400,
#   'championPointsUntilNextLevel': 200,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 35,
#   'championLevel': 3,
#   'championPoints': 11759,
#   'lastPlayTime': 1690036504000,
#   'championPointsSinceLastLevel': 5759,
#   'championPointsUntilNextLevel': 841,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 432,
#   'championLevel': 3,
#   'championPoints': 11326,
#   'lastPlayTime': 1702137051000,
#   'championPointsSinceLastLevel': 5326,
#   'championPointsUntilNextLevel': 1274,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 111,
#   'championLevel': 3,
#   'championPoints': 11232,
#   'lastPlayTime': 1678939482000,
#   'championPointsSinceLastLevel': 5232,
#   'championPointsUntilNextLevel': 1368,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 114,
#   'championLevel': 3,
#   'championPoints': 11213,
#   'lastPlayTime': 1688872796000,
#   'championPointsSinceLastLevel': 5213,
#   'championPointsUntilNextLevel': 1387,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 54,
#   'championLevel': 3,
#   'championPoints': 11109,
#   'lastPlayTime': 1686710482000,
#   'championPointsSinceLastLevel': 5109,
#   'championPointsUntilNextLevel': 1491,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 75,
#   'championLevel': 3,
#   'championPoints': 11048,
#   'lastPlayTime': 1680449055000,
#   'championPointsSinceLastLevel': 5048,
#   'championPointsUntilNextLevel': 1552,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 121,
#   'championLevel': 3,
#   'championPoints': 11034,
#   'lastPlayTime': 1702763641000,
#   'championPointsSinceLastLevel': 5034,
#   'championPointsUntilNextLevel': 1566,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 711,
#   'championLevel': 3,
#   'championPoints': 10752,
#   'lastPlayTime': 1702521711000,
#   'championPointsSinceLastLevel': 4752,
#   'championPointsUntilNextLevel': 1848,
#   'chestGranted': True,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 32,
#   'championLevel': 3,
#   'championPoints': 10493,
#   'lastPlayTime': 1664639538000,
#   'championPointsSinceLastLevel': 4493,
#   'championPointsUntilNextLevel': 2107,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 82,
#   'championLevel': 3,
#   'championPoints': 10334,
#   'lastPlayTime': 1683490426000,
#   'championPointsSinceLastLevel': 4334,
#   'championPointsUntilNextLevel': 2266,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 24,
#   'championLevel': 3,
#   'championPoints': 10289,
#   'lastPlayTime': 1701222299000,
#   'championPointsSinceLastLevel': 4289,
#   'championPointsUntilNextLevel': 2311,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 38,
#   'championLevel': 3,
#   'championPoints': 9037,
#   'lastPlayTime': 1677725349000,
#   'championPointsSinceLastLevel': 3037,
#   'championPointsUntilNextLevel': 3563,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 875,
#   'championLevel': 3,
#   'championPoints': 8928,
#   'lastPlayTime': 1687021238000,
#   'championPointsSinceLastLevel': 2928,
#   'championPointsUntilNextLevel': 3672,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 11,
#   'championLevel': 3,
#   'championPoints': 8597,
#   'lastPlayTime': 1685499767000,
#   'championPointsSinceLastLevel': 2597,
#   'championPointsUntilNextLevel': 4003,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 105,
#   'championLevel': 3,
#   'championPoints': 8564,
#   'lastPlayTime': 1687821533000,
#   'championPointsSinceLastLevel': 2564,
#   'championPointsUntilNextLevel': 4036,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 133,
#   'championLevel': 3,
#   'championPoints': 8428,
#   'lastPlayTime': 1684596399000,
#   'championPointsSinceLastLevel': 2428,
#   'championPointsUntilNextLevel': 4172,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 268,
#   'championLevel': 3,
#   'championPoints': 8267,
#   'lastPlayTime': 1657982175000,
#   'championPointsSinceLastLevel': 2267,
#   'championPointsUntilNextLevel': 4333,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 78,
#   'championLevel': 3,
#   'championPoints': 8035,
#   'lastPlayTime': 1648777531000,
#   'championPointsSinceLastLevel': 2035,
#   'championPointsUntilNextLevel': 4565,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 3,
#   'championLevel': 3,
#   'championPoints': 7828,
#   'lastPlayTime': 1663810297000,
#   'championPointsSinceLastLevel': 1828,
#   'championPointsUntilNextLevel': 4772,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 517,
#   'championLevel': 3,
#   'championPoints': 7499,
#   'lastPlayTime': 1689213681000,
#   'championPointsSinceLastLevel': 1499,
#   'championPointsUntilNextLevel': 5101,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 74,
#   'championLevel': 3,
#   'championPoints': 7094,
#   'lastPlayTime': 1684039671000,
#   'championPointsSinceLastLevel': 1094,
#   'championPointsUntilNextLevel': 5506,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 136,
#   'championLevel': 3,
#   'championPoints': 7071,
#   'lastPlayTime': 1690665208000,
#   'championPointsSinceLastLevel': 1071,
#   'championPointsUntilNextLevel': 5529,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 888,
#   'championLevel': 3,
#   'championPoints': 6803,
#   'lastPlayTime': 1689358676000,
#   'championPointsSinceLastLevel': 803,
#   'championPointsUntilNextLevel': 5797,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 7,
#   'championLevel': 3,
#   'championPoints': 6751,
#   'lastPlayTime': 1702693770000,
#   'championPointsSinceLastLevel': 751,
#   'championPointsUntilNextLevel': 5849,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 115,
#   'championLevel': 3,
#   'championPoints': 6673,
#   'lastPlayTime': 1670873186000,
#   'championPointsSinceLastLevel': 673,
#   'championPointsUntilNextLevel': 5927,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 126,
#   'championLevel': 3,
#   'championPoints': 6480,
#   'lastPlayTime': 1601702291000,
#   'championPointsSinceLastLevel': 480,
#   'championPointsUntilNextLevel': 6120,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 895,
#   'championLevel': 3,
#   'championPoints': 6287,
#   'lastPlayTime': 1701665399000,
#   'championPointsSinceLastLevel': 287,
#   'championPointsUntilNextLevel': 6313,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 777,
#   'championLevel': 2,
#   'championPoints': 5820,
#   'lastPlayTime': 1702268683000,
#   'championPointsSinceLastLevel': 4020,
#   'championPointsUntilNextLevel': 180,
#   'chestGranted': True,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 64,
#   'championLevel': 2,
#   'championPoints': 5810,
#   'lastPlayTime': 1666485380000,
#   'championPointsSinceLastLevel': 4010,
#   'championPointsUntilNextLevel': 190,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 34,
#   'championLevel': 2,
#   'championPoints': 4815,
#   'lastPlayTime': 1681055322000,
#   'championPointsSinceLastLevel': 3015,
#   'championPointsUntilNextLevel': 1185,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 58,
#   'championLevel': 2,
#   'championPoints': 4351,
#   'lastPlayTime': 1670105279000,
#   'championPointsSinceLastLevel': 2551,
#   'championPointsUntilNextLevel': 1649,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 120,
#   'championLevel': 2,
#   'championPoints': 4277,
#   'lastPlayTime': 1671077777000,
#   'championPointsSinceLastLevel': 2477,
#   'championPointsUntilNextLevel': 1723,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 246,
#   'championLevel': 2,
#   'championPoints': 4252,
#   'lastPlayTime': 1701818573000,
#   'championPointsSinceLastLevel': 2452,
#   'championPointsUntilNextLevel': 1748,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 897,
#   'championLevel': 2,
#   'championPoints': 4248,
#   'lastPlayTime': 1702749857000,
#   'championPointsSinceLastLevel': 2448,
#   'championPointsUntilNextLevel': 1752,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 13,
#   'championLevel': 2,
#   'championPoints': 4108,
#   'lastPlayTime': 1669520348000,
#   'championPointsSinceLastLevel': 2308,
#   'championPointsUntilNextLevel': 1892,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 12,
#   'championLevel': 2,
#   'championPoints': 4051,
#   'lastPlayTime': 1656209237000,
#   'championPointsSinceLastLevel': 2251,
#   'championPointsUntilNextLevel': 1949,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 42,
#   'championLevel': 2,
#   'championPoints': 3871,
#   'lastPlayTime': 1655331743000,
#   'championPointsSinceLastLevel': 2071,
#   'championPointsUntilNextLevel': 2129,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 523,
#   'championLevel': 2,
#   'championPoints': 3616,
#   'lastPlayTime': 1702753475000,
#   'championPointsSinceLastLevel': 1816,
#   'championPointsUntilNextLevel': 2384,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 266,
#   'championLevel': 2,
#   'championPoints': 3471,
#   'lastPlayTime': 1676438303000,
#   'championPointsSinceLastLevel': 1671,
#   'championPointsUntilNextLevel': 2529,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 234,
#   'championLevel': 2,
#   'championPoints': 3077,
#   'lastPlayTime': 1698010648000,
#   'championPointsSinceLastLevel': 1277,
#   'championPointsUntilNextLevel': 2923,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 33,
#   'championLevel': 2,
#   'championPoints': 2862,
#   'lastPlayTime': 1676163697000,
#   'championPointsSinceLastLevel': 1062,
#   'championPointsUntilNextLevel': 3138,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 555,
#   'championLevel': 2,
#   'championPoints': 2635,
#   'lastPlayTime': 1658801508000,
#   'championPointsSinceLastLevel': 835,
#   'championPointsUntilNextLevel': 3365,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 164,
#   'championLevel': 2,
#   'championPoints': 2607,
#   'lastPlayTime': 1612859117000,
#   'championPointsSinceLastLevel': 807,
#   'championPointsUntilNextLevel': 3393,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 56,
#   'championLevel': 2,
#   'championPoints': 2443,
#   'lastPlayTime': 1661700100000,
#   'championPointsSinceLastLevel': 643,
#   'championPointsUntilNextLevel': 3557,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 59,
#   'championLevel': 2,
#   'championPoints': 2267,
#   'lastPlayTime': 1658870234000,
#   'championPointsSinceLastLevel': 467,
#   'championPointsUntilNextLevel': 3733,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 5,
#   'championLevel': 2,
#   'championPoints': 2120,
#   'lastPlayTime': 1667684643000,
#   'championPointsSinceLastLevel': 320,
#   'championPointsUntilNextLevel': 3880,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 62,
#   'championLevel': 2,
#   'championPoints': 2042,
#   'lastPlayTime': 1668791765000,
#   'championPointsSinceLastLevel': 242,
#   'championPointsUntilNextLevel': 3958,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 86,
#   'championLevel': 2,
#   'championPoints': 2027,
#   'lastPlayTime': 1683513121000,
#   'championPointsSinceLastLevel': 227,
#   'championPointsUntilNextLevel': 3973,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 166,
#   'championLevel': 2,
#   'championPoints': 1918,
#   'lastPlayTime': 1702826881000,
#   'championPointsSinceLastLevel': 118,
#   'championPointsUntilNextLevel': 4082,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 6,
#   'championLevel': 1,
#   'championPoints': 1745,
#   'lastPlayTime': 1618720161000,
#   'championPointsSinceLastLevel': 1745,
#   'championPointsUntilNextLevel': 55,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 122,
#   'championLevel': 1,
#   'championPoints': 1616,
#   'lastPlayTime': 1658459931000,
#   'championPointsSinceLastLevel': 1616,
#   'championPointsUntilNextLevel': 184,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 113,
#   'championLevel': 1,
#   'championPoints': 1458,
#   'lastPlayTime': 1666835594000,
#   'championPointsSinceLastLevel': 1458,
#   'championPointsUntilNextLevel': 342,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 526,
#   'championLevel': 1,
#   'championPoints': 1410,
#   'lastPlayTime': 1689388196000,
#   'championPointsSinceLastLevel': 1410,
#   'championPointsUntilNextLevel': 390,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 80,
#   'championLevel': 1,
#   'championPoints': 1392,
#   'lastPlayTime': 1702695617000,
#   'championPointsSinceLastLevel': 1392,
#   'championPointsUntilNextLevel': 408,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 91,
#   'championLevel': 1,
#   'championPoints': 1329,
#   'lastPlayTime': 1690508001000,
#   'championPointsSinceLastLevel': 1329,
#   'championPointsUntilNextLevel': 471,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 36,
#   'championLevel': 1,
#   'championPoints': 1239,
#   'lastPlayTime': 1668732787000,
#   'championPointsSinceLastLevel': 1239,
#   'championPointsUntilNextLevel': 561,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 48,
#   'championLevel': 1,
#   'championPoints': 1202,
#   'lastPlayTime': 1659851577000,
#   'championPointsSinceLastLevel': 1202,
#   'championPointsUntilNextLevel': 598,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 106,
#   'championLevel': 1,
#   'championPoints': 1172,
#   'lastPlayTime': 1669950928000,
#   'championPointsSinceLastLevel': 1172,
#   'championPointsUntilNextLevel': 628,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 233,
#   'championLevel': 1,
#   'championPoints': 1147,
#   'lastPlayTime': 1702787820000,
#   'championPointsSinceLastLevel': 1147,
#   'championPointsUntilNextLevel': 653,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 2,
#   'championLevel': 1,
#   'championPoints': 995,
#   'lastPlayTime': 1440280707000,
#   'championPointsSinceLastLevel': 995,
#   'championPointsUntilNextLevel': 805,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 79,
#   'championLevel': 1,
#   'championPoints': 964,
#   'lastPlayTime': 1560385082000,
#   'championPointsSinceLastLevel': 964,
#   'championPointsUntilNextLevel': 836,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 223,
#   'championLevel': 1,
#   'championPoints': 962,
#   'lastPlayTime': 1687307186000,
#   'championPointsSinceLastLevel': 962,
#   'championPointsUntilNextLevel': 838,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 19,
#   'championLevel': 1,
#   'championPoints': 919,
#   'lastPlayTime': 1683237459000,
#   'championPointsSinceLastLevel': 919,
#   'championPointsUntilNextLevel': 881,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 20,
#   'championLevel': 1,
#   'championPoints': 794,
#   'lastPlayTime': 1494582253000,
#   'championPointsSinceLastLevel': 794,
#   'championPointsUntilNextLevel': 1006,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 27,
#   'championLevel': 1,
#   'championPoints': 672,
#   'lastPlayTime': 1660401984000,
#   'championPointsSinceLastLevel': 672,
#   'championPointsUntilNextLevel': 1128,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 950,
#   'championLevel': 1,
#   'championPoints': 488,
#   'lastPlayTime': 1702829828000,
#   'championPointsSinceLastLevel': 488,
#   'championPointsUntilNextLevel': 1312,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 154,
#   'championLevel': 1,
#   'championPoints': 242,
#   'lastPlayTime': 1676786912000,
#   'championPointsSinceLastLevel': 242,
#   'championPointsUntilNextLevel': 1558,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 83,
#   'championLevel': 1,
#   'championPoints': 194,
#   'lastPlayTime': 1468895388000,
#   'championPointsSinceLastLevel': 194,
#   'championPointsUntilNextLevel': 1606,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 14,
#   'championLevel': 1,
#   'championPoints': 161,
#   'lastPlayTime': 1502550090000,
#   'championPointsSinceLastLevel': 161,
#   'championPointsUntilNextLevel': 1639,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 238,
#   'championLevel': 1,
#   'championPoints': 126,
#   'lastPlayTime': 1480106721000,
#   'championPointsSinceLastLevel': 126,
#   'championPointsUntilNextLevel': 1674,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 516,
#   'championLevel': 1,
#   'championPoints': 104,
#   'lastPlayTime': 1602270530000,
#   'championPointsSinceLastLevel': 104,
#   'championPointsUntilNextLevel': 1696,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 420,
#   'championLevel': 1,
#   'championPoints': 103,
#   'lastPlayTime': 1635127332000,
#   'championPointsSinceLastLevel': 103,
#   'championPointsUntilNextLevel': 1697,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'},
#  {'puuid': 'lXYH_RFUKyaBmlgvHAltJq9rOcu-UCH1_DBbVTM9QUA3ITPgHGrKmpGLbsVJoIPE1Lz1b74uR5E66A',
#   'championId': 107,
#   'championLevel': 1,
#   'championPoints': 72,
#   'lastPlayTime': 1648859679000,
#   'championPointsSinceLastLevel': 72,
#   'championPointsUntilNextLevel': 1728,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'YF1OzBQF2XhkKVV0npPVrdaJeD2R929mn0iJBphmMFlhtpUR'}]

# %%
def commit_champ_mastery(conn, summoner_name):
    with conn.cursor() as curs:
        cur.execute ('''DROP TABLE
              "YRDEN".lol_champ_mastery''')
        cur.execute('''CREATE TABLE "YRDEN".lol_champ_mastery
                    (puuid varchar , 
                    summonerId varchar,
                    championId int , 
                    championLevel int ,
                    championPoints int ,
                    championPointsUntilNextLevel int,
                    championPointsSinceLastLevel int,
                    chestGranted boolean,
                    lastPlayTime timestamp,
                    tokensEarned int
                    )
                    ;
                    ''')
        for i, riot_puuid in enumerate(summoner_name):
            api_url = f"https://na1.api.riotgames.com/lol/champion-mastery/v4/champion-masteries/by-puuid/{riot_puuid}?api_key={api_key}"
            resp = requests.get(api_url)
            vals = resp.json()
            new_vals = {}
            for n in range(len(vals)):
                new_vals.update({'puuid' : vals[n]['puuid'],
                                'summonerId' : vals[n]['summonerId'],
                                 'championId' : vals[n]['championId'],
                                 'championLevel' : vals[n]['championLevel'],
                                 'championPoints' :  vals[n]['championPoints'],
                                 'championPointsUntilNextLevel' :  vals[n]['championPointsUntilNextLevel'],
                                 'championPointsSinceLastLevel' :  vals[n]['championPointsSinceLastLevel'],
                                 'chestGranted' :  vals[n]['chestGranted'],
                                 'tokensEarned' :  vals[n]['tokensEarned']
                                })

                curs.execute('''DROP TABLE "YRDEN".stage_champ_mastery;''')

                curs.execute('''CREATE TABLE "YRDEN".stage_champ_mastery
                            (puuid varchar , 
                                        summonerId varchar,
                                        championId int , 
                                        championLevel int ,
                                        championPoints int ,
                                        championPointsUntilNextLevel int,
                                        championPointsSinceLastLevel int,
                                        chestGranted boolean,
                                        tokensEarned int
                                        );''')
                #print(new_vals)

                curs.execute('''INSERT INTO "YRDEN".stage_champ_mastery 
                            (puuid, 
                            summonerId,
                            championId,
                            championLevel,
                            championPoints,
                            championPointsUntilNextLevel,
                            championPointsSinceLastLevel,
                            chestGranted,
                           tokensEarned
                            )
                                VALUES (%(puuid)s, %(summonerId)s, %(championId)s,
                                %(championLevel)s, %(championPoints)s,
                                %(championPointsUntilNextLevel)s,
                                %(championPointsSinceLastLevel)s, 
                                %(chestGranted)s,   %(tokensEarned)s);''', new_vals)



                curs.execute('''INSERT INTO "YRDEN".lol_champ_mastery (puuid, 
                            summonerId,
                            championId,
                            championLevel,
                            championPoints,
                            championPointsUntilNextLevel,
                            championPointsSinceLastLevel,
                            chestGranted,
                            tokensEarned
                            )
                                SELECT DISTINCT cmst.puuid, 
                            cmst.summonerId,
                            cmst.championId,
                            cmst.championLevel,
                            cmst.championPoints,
                            cmst.championPointsUntilNextLevel,
                            cmst.championPointsSinceLastLevel,
                            cmst.chestGranted,
                            cmst.tokensEarned
                                FROM "YRDEN".stage_champ_mastery cmst
                                WHERE NOT EXISTS (SELECT puuid,
                                summonerId, championId
                                FROM "YRDEN".lol_champ_mastery cmt
                                WHERE cmst.puuid = cmt.puuid
                                AND cmst.summonerId = cmt.summonerId
                                AND cmst.championId = cmt.championId);
                                 ''')
                            
                conn.commit()
            curs.execute('''SELECT DISTINCT CHAMPIONID FROM "YRDEN".LOL_CHAMP_MASTERY WHERE PUUID = %s;''', (riot_puuid,))
            print(curs.rowcount, " champions added for ", i)

# %%
cur.execute('SELECT riot_puuid FROM "YRDEN".yrden_people WHERE summoner_name is NOT NULL AND riot_puuid is NOT NULL')
result = cur.fetchall()
res = [result[0] for result in result]
res
commit_champ_mastery(conn, res)
# Out:
# 161  champions added for  0
# 134  champions added for  1
# 162  champions added for  2
# 163  champions added for  3
# 144  champions added for  4
# 164  champions added for  5
# 138  champions added for  6
# 158  champions added for  7
# 153  champions added for  8
# 141  champions added for  9
# 165  champions added for  10
# 162  champions added for  11
# 147  champions added for  12
# 110  champions added for  13

# %%
conn.close()

# %%
#
DDRegion = lol_watcher.data_dragon.versions_for_region('na1')['n']
DDItem = DDRegion['item']

# %%
DDRegion

# %%
lol_watcher.data_dragon.items(DDItem)
